# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r'C:\Users\shiva\Downloads\DOWNLOADS\Data Science\Projects\Actual Projects\CIMT inflammation\Final Master Chart (Cleaned Data).xlsx')

# %%
df.head()
# Out:
#    s.no       Ip.no  age sex  duration of disease in year  TJC  SJC  ESR  CRP  \
# 0     1  1107012263   60   F                            9   26    6   50  2.0
# 1    22  2015736936   60   F                            4   14    0   34  1.0
# 2    30  2214526959   60   F                            6   20   10   30  2.0
# 3    36  1114444061   60   F                            7   18    6   50  2.0
# 4    37  1115654424   60   F                           10   20    8   45  1.0
#
#    Anti CCP        RF  CIMT IN (MM)
# 0  positive  positive          1.23
# 1  positive  positive          1.19
# 2  positive  positive          1.21
# 3  positive  positive          1.17
# 4  positive  positive          1.23

# %%
df.drop(['s.no','Ip.no'],axis=1,inplace=True)

# %% [markdown]
# # These 2 feature are irrelevant for our data analysis

# %%
df.head()
# Out:
#    age sex  duration of disease in year  TJC  SJC  ESR  CRP  Anti CCP  \
# 0   60   F                            9   26    6   50  2.0  positive
# 1   60   F                            4   14    0   34  1.0  positive
# 2   60   F                            6   20   10   30  2.0  positive
# 3   60   F                            7   18    6   50  2.0  positive
# 4   60   F                           10   20    8   45  1.0  positive
#
#          RF  CIMT IN (MM)
# 0  positive          1.23
# 1  positive          1.19
# 2  positive          1.21
# 3  positive          1.17
# 4  positive          1.23

# %%
df.isnull().sum()
# Out:
# age                            0
# sex                            0
# duration of disease in year    0
# TJC                            0
# SJC                            0
# ESR                            0
# CRP                            0
# Anti CCP                       0
# RF                             0
# CIMT IN (MM)                   0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   age                          140 non-null    int64
#  1   sex                          140 non-null    object
#  2   duration of disease in year  140 non-null    int64
#  3   TJC                          140 non-null    int64
#  4   SJC                          140 non-null    int64
#  5   ESR                          140 non-null    int64
#  6   CRP                          140 non-null    float64
#  7   Anti CCP                     140 non-null    object
#  8   RF                           140 non-null    object
#  9   CIMT IN (MM)                 140 non-null    float64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 11.1+ KB

# %%
df.describe()
# Out:
#               age  duration of disease in year         TJC         SJC  \
# count  140.000000                   140.000000  140.000000  140.000000
# mean    41.671429                     5.135714   10.700000    6.814286
# std     10.378064                     2.149823    5.862575    4.495538
# min     20.000000                     0.000000    2.000000    0.000000
# 25%     34.000000                     4.000000    6.000000    4.000000
# 50%     40.000000                     5.000000    8.000000    6.000000
# 75%     49.000000                     7.000000   14.500000   10.000000
# max     61.000000                    10.000000   26.000000   20.000000
#
#               ESR         CRP  CIMT IN (MM)
# count  140.000000  140.000000    140.000000
# mean    40.914286    1.177143      0.766643
# std     12.207726    0.628157      0.237367
# min     20.000000    0.300000      0.450000
# 25%     30.000000    0.800000      0.590000
# 50%     40.000000    1.000000      0.720000
# ...

# %%
df['Anti CCP'].value_counts()
# Out:
# Anti CCP
# positive    140
# Name: count, dtype: int64

# %%
df['RF'].value_counts()
# Out:
# RF
# positive    140
# Name: count, dtype: int64

# %%
plt.figure(figsize=(3,5))
sns.countplot(data=df,x=df['RF'])
plt.show()

# %%
plt.figure(figsize=(3,5))
sns.countplot(data=df,x=df['Anti CCP'],color='c')
plt.show()

# %%
df.drop(['Anti CCP','RF'],axis=1,inplace=True)

# %% [markdown]
# # Only 1 data value for both the features.No variation in data so not so significant for our analysis

# %%
df
# Out:
#      age sex  duration of disease in year  TJC  SJC  ESR  CRP  CIMT IN (MM)
# 0     60   F                            9   26    6   50  2.0          1.23
# 1     60   F                            4   14    0   34  1.0          1.19
# 2     60   F                            6   20   10   30  2.0          1.21
# 3     60   F                            7   18    6   50  2.0          1.17
# 4     60   F                           10   20    8   45  1.0          1.23
# ..   ...  ..                          ...  ...  ...  ...  ...           ...
# 135   26   F                            3    8    4   35  0.5          0.61
# 136   24   F                            2    4    2   30  0.3          0.63
# 137   24   M                            4    8    2   35  1.0          0.66
# 138   24   F                            4    9    4   60  0.7          0.59
# 139   20   M                            2    6    2   64  1.0          0.59
#
# [140 rows x 8 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['sex'] = le.fit_transform(df['sex'])

# %% [markdown]
# # Converting the sex feature data type as it is categorical data, need to convert in numerical data for prediction model

# %%
df
# Out:
#      age  sex  duration of disease in year  TJC  SJC  ESR  CRP  CIMT IN (MM)
# 0     60    0                            9   26    6   50  2.0          1.23
# 1     60    0                            4   14    0   34  1.0          1.19
# 2     60    0                            6   20   10   30  2.0          1.21
# 3     60    0                            7   18    6   50  2.0          1.17
# 4     60    0                           10   20    8   45  1.0          1.23
# ..   ...  ...                          ...  ...  ...  ...  ...           ...
# 135   26    0                            3    8    4   35  0.5          0.61
# 136   24    0                            2    4    2   30  0.3          0.63
# 137   24    1                            4    8    2   35  1.0          0.66
# 138   24    0                            4    9    4   60  0.7          0.59
# 139   20    1                            2    6    2   64  1.0          0.59
#
# [140 rows x 8 columns]

# %%
df['sex'].value_counts()
# Out:
# sex
# 0    101
# 1     39
# Name: count, dtype: int64

# %%
plt.figure
sns.scatterplot(data=df,x='age',y='CIMT IN (MM)')
plt.show()

# %%
from warnings import filterwarnings
filterwarnings('ignore')

from scipy.stats import skew

# %%
for col in df:
    print(col)
    print(skew(df[col]))
    
    plt.figure
    sns.distplot(df[col])
    plt.show()
# Out:
# age
# 0.21353502229740465
# sex
# 0.9878675030615066
# duration of disease in year
# -0.006472579340515661
# TJC
# 0.75683312827861
# SJC
# 1.0121151528594459
# ESR
# 0.2962116462741215
# CRP
# 2.1453635070857495
# CIMT IN (MM)
# 0.8676163920102211

# %%
df['CRP'] = np.sqrt(df['CRP'])

# %%
print(skew(df['CRP']))
# Out:
# 1.1983612778253703

# %% [markdown]
# # Correcting the skewness of CRP feature

# %%
plt.figure(figsize=(20,20))
sns.pairplot(df[['age','sex','duration of disease in year','ESR','CRP','CIMT IN (MM)']])

# %%
df
# Out:
#      age  sex  duration of disease in year  TJC  SJC  ESR       CRP  \
# 0     60    0                            9   26    6   50  1.414214
# 1     60    0                            4   14    0   34  1.000000
# 2     60    0                            6   20   10   30  1.414214
# 3     60    0                            7   18    6   50  1.414214
# 4     60    0                           10   20    8   45  1.000000
# ..   ...  ...                          ...  ...  ...  ...       ...
# 135   26    0                            3    8    4   35  0.707107
# 136   24    0                            2    4    2   30  0.547723
# 137   24    1                            4    8    2   35  1.000000
# 138   24    0                            4    9    4   60  0.836660
# 139   20    1                            2    6    2   64  1.000000
#
#      CIMT IN (MM)
# 0            1.23
# 1            1.19
# 2            1.21
# 3            1.17
# 4            1.23
# ..            ...
# ...

# %%
x = df.drop(['CIMT IN (MM)'],axis=1)
y = df['CIMT IN (MM)']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=12)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

models = {
    'DecisionTreeRegressor': DecisionTreeRegressor(),
    'RandomForestRegressor': RandomForestRegressor(),
    'KNeighborsRegressor': KNeighborsRegressor(),
    'AdaBoostRegressor': AdaBoostRegressor(),
    'GradientBoostingRegressor': GradientBoostingRegressor(),
    'BaggingRegressor': BaggingRegressor(),
    'LinearRegression': LinearRegression(),
}

for model_name, model in models.items():
    model.fit(X_train, y_train)
    
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)
    
    model_train_MAE = mean_absolute_error(y_train, y_train_pred)
    model_train_MSE = mean_squared_error(y_train, y_train_pred)
    model_train_RMSE = np.sqrt(model_train_MSE)
    model_train_r2_score = r2_score(y_train, y_train_pred)
    
    print(model_name)
    print('Model Performance for training set')
    print(f'- MAE : {model_train_MAE:.4f}')
    print(f'- MSE : {model_train_MSE:.4f}')
    print(f'- RMSE : {model_train_RMSE:.4f}')
    print(f'- r2_score : {model_train_r2_score:.4f}')
    print('-'*35)
    
    
    model_score = model.score(X_test, y_test)
    model_test_MAE = mean_absolute_error(y_test, y_test_pred)
    model_test_MSE = mean_squared_error(y_test, y_test_pred)
    model_test_RMSE = np.sqrt(model_test_MSE)
    model_test_r2_score = r2_score(y_test, y_test_pred)
    
    print('Model Performance for testing set')
    print()
    print(f'Model Score : {model_score:.4f}')
    print()
    print(f'- MAE : {model_test_MAE:.4f}')
    print(f'- MSE : {model_test_MSE:.4f}')
    print(f'- RMSE : {model_test_RMSE:.4f}')
    print(f'- r2_score : {model_test_r2_score:.4f}')
    print('='*35)
    print('\n')
# Out:
# DecisionTreeRegressor
# Model Performance for training set
# - MAE : 0.0000
# - MSE : 0.0000
# - RMSE : 0.0000
# - r2_score : 1.0000
# -----------------------------------
# Model Performance for testing set
#
# Model Score : 0.4271
#
# - MAE : 0.1232
# - MSE : 0.0278
# - RMSE : 0.1668
# - r2_score : 0.4271
# ...
#
#
# RandomForestRegressor
# Model Performance for training set
# - MAE : 0.0464
# - MSE : 0.0041
# - RMSE : 0.0642
# - r2_score : 0.9286
# -----------------------------------
# Model Performance for testing set
#
# Model Score : 0.6665
#
# - MAE : 0.0892
# - MSE : 0.0162
# - RMSE : 0.1272
# - r2_score : 0.6665
# ...
#
#
# KNeighborsRegressor
# Model Performance for training set
# - MAE : 0.1070
# - MSE : 0.0222
# - RMSE : 0.1490
# - r2_score : 0.6153
# -----------------------------------
# Model Performance for testing set
#
# Model Score : 0.3297
#
# - MAE : 0.1473
# - MSE : 0.0325
# - RMSE : 0.1804
# - r2_score : 0.3297
# ...
#
#
# AdaBoostRegressor
# Model Performance for training set
# ...

# %%
from sklearn.linear_model import LinearRegression
le = LinearRegression()
le.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
feature_importances_linear = le.coef_
feature_importances_linear = pd.Series(feature_importances_linear, index=X_train.columns)
sorted_feature_importances_linear = feature_importances_linear.abs().sort_values(ascending=False)

# %%
plt.figure(figsize=(10, 6))
sorted_feature_importances_linear.plot(kind='barh')
plt.title('Feature Importance')# (Linear Regression)
plt.ylabel('Coefficient Magnitude')
plt.xlabel('Features')
plt.show()

# %%
df1 = df[df['CIMT IN (MM)']>1]
df2 = df[df['CIMT IN (MM)']<=1]
df1['CIMT inflammation'] = '1'
df2['CIMT inflammation'] = '0'
df = pd.concat((df1,df2),axis=0)

# %%
df.head()
# Out:
#    age  sex  duration of disease in year  TJC  SJC  ESR       CRP  \
# 0   60    0                            9   26    6   50  1.414214
# 1   60    0                            4   14    0   34  1.000000
# 2   60    0                            6   20   10   30  1.414214
# 3   60    0                            7   18    6   50  1.414214
# 4   60    0                           10   20    8   45  1.000000
#
#    CIMT IN (MM) CIMT inflammation
# 0          1.23                 Y
# 1          1.19                 Y
# 2          1.21                 Y
# 3          1.17                 Y
# 4          1.23                 Y

# %% [markdown]
# # Creating a new column 'CIMT inflammation', which has categorical data and used as a dependent variable in classification models

# %%
x = df.drop(['CIMT IN (MM)','CIMT inflammation'],axis=1)
y = df['CIMT inflammation']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=12)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.cluster import KMeans
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score, roc_auc_score
import numpy as np

models = {
    'DecisionTreeClassifier': DecisionTreeClassifier(),
    'RandomForestClassifier': RandomForestClassifier(),
    'KNeighborsClassifier': KNeighborsClassifier(),
    'AdaBoostClassifier': AdaBoostClassifier(),
    'GradientBoostingClassifier': GradientBoostingClassifier(),
    'BaggingClassifier': BaggingClassifier(),
    'LogisticRegression': LogisticRegression(),
    'KMeans': KMeans(),
    'SVC': SVC()
}

for model_name, model in models.items():
    model.fit(X_train, y_train)
    
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)
    
    model_train_score = model.score(X_train, y_train)
    model_train_accuracy = accuracy_score(y_train, y_train_pred)
    # For multiclass classification, specify the average parameter for precision, recall, and f1_score
    model_train_f1 = f1_score(y_train, y_train_pred, average='weighted')
    model_train_precision = precision_score(y_train, y_train_pred, average='weighted')
    model_train_recall = recall_score(y_train, y_train_pred, average='weighted')
    
    print(model_name)
    print('Model Performance for training set')
    print(f'- Score : {model_train_score:.4f}', end='\n')
    print(f'- Accuracy : {model_train_accuracy:.4f}')
    print(f'- f1 : {model_train_f1:.4f}')
    print(f'- Precision : {model_train_precision:.4f}')
    print(f'- Recall : {model_train_recall:.4f}')
    print('-' * 35)
    
    model_test_score = model.score(X_test, y_test)
    model_test_accuracy = accuracy_score(y_test, y_test_pred)
    # For multiclass classification, specify the average parameter for precision, recall, and f1_score
    model_test_f1 = f1_score(y_test, y_test_pred, average='weighted')
    model_test_precision = precision_score(y_test, y_test_pred, average='weighted')
    model_test_recall = recall_score(y_test, y_test_pred, average='weighted')
    
    print('Model Performance for testing set')
    print()
    print(f'- Score : {model_test_score:.4f}', end='\n'*2)
    print(f'- Accuracy : {model_test_accuracy:.4f}')
    print(f'- f1 : {model_test_f1:.4f}')
    print(f'- Precision : {model_test_precision:.4f}')
    print(f'- Recall : {model_test_recall:.4f}')
    print('=' * 35)
    print('\n')
# Out:
# DecisionTreeClassifier
# Model Performance for training set
# - Score : 1.0000
# - Accuracy : 1.0000
# - f1 : 1.0000
# - Precision : 1.0000
# - Recall : 1.0000
# -----------------------------------
# Model Performance for testing set
#
# - Score : 0.8214
#
# - Accuracy : 0.8214
# - f1 : 0.8030
# - Precision : 0.8125
# - Recall : 0.8214
# ...
#
#
# RandomForestClassifier
# Model Performance for training set
# - Score : 1.0000
# - Accuracy : 1.0000
# - f1 : 1.0000
# - Precision : 1.0000
# - Recall : 1.0000
# -----------------------------------
# Model Performance for testing set
#
# - Score : 0.8571
#
# - Accuracy : 0.8571
# - f1 : 0.8348
# - Precision : 0.8800
# - Recall : 0.8571
# ...
#
#
# KNeighborsClassifier
# Model Performance for training set
# - Score : 0.9107
# - Accuracy : 0.9107
# - f1 : 0.9032
# - Precision : 0.9126
# - Recall : 0.9107
# -----------------------------------
# Model Performance for testing set
#
# - Score : 0.6786
#
# - Accuracy : 0.6786
# - f1 : 0.6455
# ...

# %% [markdown]
# # Among all the models bagging is performing the most optimum

# %%
df['CIMT inflammation']

# %% [markdown]
# #BaggingClassifier()

# %%
from sklearn.ensemble import BaggingClassifier
bag = BaggingClassifier()
bag.fit(X_train,y_train)

# %%
bag.predict(X_test)

# %%
bag.score(X_train,y_train)

# %%
bag.score(X_test,y_test)

# %% [markdown]
# #BaggingClassifier(estimator=SVC())

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=12)

from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
clf = BaggingClassifier(estimator=SVC(),n_estimators=10, random_state=0)
clf.fit(X_train,y_train)

# %%
clf.score(X_train,y_train)

# %%
clf.score(X_test,y_test)

# %%
clf.predict(X_test)

# %% [markdown]
# #AdaBoostClassifier(estimator=BaggingClassifier())

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=10)

from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier,AdaBoostClassifier
ada = AdaBoostClassifier(estimator=BaggingClassifier(),n_estimators=12, random_state=0)
ada.fit(X_train,y_train)

# %%
ada.score(X_train,y_train)

# %%
ada.score(X_test,y_test)

# %% [markdown]
# # BaggingClassifier(estimator=AdaBoostClassifier())

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=10)

from sklearn.ensemble import BaggingClassifier
clf = BaggingClassifier(estimator=AdaBoostClassifier(),n_estimators=12, random_state=0)
clf.fit(X_train,y_train)

# %%
clf.score(X_train,y_train)

# %%
clf.score(X_test,y_test)

# %% [markdown]
# # We used bagging model and estimator as AdaBoostClassifier, the model score is 0.9285714285714286 on testing data

# %%
y_train_pred = clf.predict(X_train)
y_test_pred = clf.predict(X_test)

model_train_score = clf.score(X_train, y_train)
model_train_accuracy = accuracy_score(y_train, y_train_pred)
 
model_train_f1 = f1_score(y_train, y_train_pred, average='weighted')
model_train_precision = precision_score(y_train, y_train_pred, average='weighted')
model_train_recall = recall_score(y_train, y_train_pred, average='weighted')
    
print('Bagging model and estimator as AdaBoostClassifier:-')
print()
print('Model Performance for training set')
print()
print(f'- Score : {model_train_score:.4f}', end='\n'*2)
print(f'- Accuracy : {model_train_accuracy:.4f}')
print(f'- f1 : {model_train_f1:.4f}')
print(f'- Precision : {model_train_precision:.4f}')
print(f'- Recall : {model_train_recall:.4f}')
print('-' * 35)
    
model_test_score = clf.score(X_test, y_test)
model_test_accuracy = accuracy_score(y_test, y_test_pred)
model_test_f1 = f1_score(y_test, y_test_pred, average='weighted')
model_test_precision = precision_score(y_test, y_test_pred, average='weighted')
model_test_recall = recall_score(y_test, y_test_pred, average='weighted')

print('Model Performance for testing set')
print()
print(f'- Score : {model_test_score:.4f}', end='\n'*2)
print(f'- Accuracy : {model_test_accuracy:.4f}')
print(f'- f1 : {model_test_f1:.4f}')
print(f'- Precision : {model_test_precision:.4f}')
print(f'- Recall : {model_test_recall:.4f}')
print('=' * 35)
print('\n')
